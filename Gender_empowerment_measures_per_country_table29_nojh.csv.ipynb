# %%
import pandas as pd
import numpy as np


df = pd.read_excel(r"C:\Users\PCHOME\Desktop\data-wrangling-and-validation\data\lesson-spreadsheet\HDR_2007_2008_Table _29.xlsx")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 33 columns):
# Unnamed: 0     206 non-null object
# Unnamed: 1     198 non-null object
# Unnamed: 2     21 non-null object
# Unnamed: 3     199 non-null object
# Unnamed: 4     0 non-null float64
# Unnamed: 5     178 non-null object
# Unnamed: 6     20 non-null float64
# Unnamed: 7     200 non-null object
# Unnamed: 8     9 non-null object
# Unnamed: 9     179 non-null object
# Unnamed: 10    26 non-null object
# Unnamed: 11    199 non-null object
# Unnamed: 12    8 non-null object
# Unnamed: 13    191 non-null object
# Unnamed: 14    13 non-null object
# Unnamed: 15    0 non-null float64
# Unnamed: 16    0 non-null float64
# Unnamed: 17    0 non-null float64
# Unnamed: 18    0 non-null float64
# Unnamed: 19    0 non-null float64
# Unnamed: 20    0 non-null float64
# Unnamed: 21    0 non-null float64
# Unnamed: 22    0 non-null float64
# Unnamed: 23    0 non-null float64
# ...

# %%
df.head(14)
# Out:
#                          Unnamed: 0 Unnamed: 1  \
# 0                               NaN        NaN
# 1   29  Gender empowerment measure         NaN
# 2                               NaN        NaN
# 3                               NaN        NaN
# 4   25  Gender empowerment measure         NaN
# 5                               NaN        NaN
# 6                               NaN        NaN
# 7                               NaN        NaN
# 8                               NaN        NaN
# 9                               NaN        NaN
# 10                              NaN        NaN
# 11                         HDI rank        NaN
# 12                              NaN        NaN
# 13           HIGH HUMAN DEVELOPMENT        NaN
#
#                                         Unnamed: 2  \
# 0   … and achieving equality for all women and men
# 1                                              NaN
# 2                                              NaN
# ...

# %%
df=pd.read_excel(r"C:\Users\PCHOME\Desktop\data-wrangling-and-validation\data\lesson-spreadsheet\HDR_2007_2008_Table _29.xlsx",header=12)

# %%
df
# Out:
#                                               HDI rank  \
# 0                                                  NaN
# 1                               HIGH HUMAN DEVELOPMENT
# 2                                                    1
# 3                                                    2
# 4                                                    3
# 5                                                    4
# 6                                                    5
# 7                                                    6
# 8                                                    7
# 9                                                    8
# 10                                                   9
# 11                                                  10
# 12                                                  11
# 13                                                  12
# 14                                                  13
# 15                                                  14
# ...

# %%
df = df.dropna(how="all",axis=1)
df = df.dropna(how="all",axis=0)
df = df.reset_index(drop=True)
df.head(6)
# Out:
#                  HDI rank Unnamed: 1  Unnamed: 2  \
# 0                     NaN        NaN         NaN
# 1  HIGH HUMAN DEVELOPMENT        NaN         NaN
# 2                       1    Iceland         NaN
# 3                       2     Norway         NaN
# 4                       3  Australia         NaN
# 5                       4     Canada         NaN
#
#   Gender empowerment measure \n(GEM)    Unnamed: 5  Unnamed: 6  \
# 0                               Rank  Value                NaN
# 1                                NaN           NaN         NaN
# 2                                  5         0.862         NaN
# 3                                  1         0.910         NaN
# 4                                  8         0.847         NaN
# 5                                 10         0.820         NaN
#
#   Seats in parliament \nheld by womena Unnamed: 8  \
# 0                         (% of total)        NaN
# 1                                  NaN        NaN
# ...

# %%
columns =[]
for c in df.columns:
    columns.append([str(v) for v in df[c][0:1] if pd.notnull(v)])

print(columns)
# Out:
# [[], [], [], ['Rank'], ['Value       '], [], ['(% of total)'], [], [' (% of total)'], [], ['(% of total)'], [], [], []]

# %%
columns = ['HDI_rank','country','reference_1',
       'GEM_rank', 'GEM_value',
       'reference_2', 'Seats_parlia_wom', 'reference_3',
       'Fem _le_snr_offi_mana', 'reference_4',
       'Fem_profes_techn_work', 'reference_5',
       'Ratio_esti_ fem_male_earn_ incom','reference_6']

df.columns = columns



df = df.drop(np.arange(1), axis=0).reset_index(drop=True)
df.head()
# Out:
#                  HDI_rank    country  reference_1 GEM_rank GEM_value  \
# 0  HIGH HUMAN DEVELOPMENT        NaN          NaN      NaN       NaN
# 1                       1    Iceland          NaN        5     0.862
# 2                       2     Norway          NaN        1     0.910
# 3                       3  Australia          NaN        8     0.847
# 4                       4     Canada          NaN       10     0.820
#
#    reference_2 Seats_parlia_wom reference_3 Fem _le_snr_offi_mana reference_4  \
# 0          NaN              NaN         NaN                   NaN         NaN
# 1          NaN             31.7         NaN                    27         NaN
# 2          NaN             37.9         NaN                    30         NaN
# 3          NaN             28.3         NaN                    37         NaN
# 4          NaN             24.3         NaN                    36         NaN
#
#   Fem_profes_techn_work reference_5 Ratio_esti_ fem_male_earn_ incom  \
# ...

# %%
df.tail(90)
# Out:
#                                               HDI_rank  \
# 114                                                113
# 115                                                114
# 116                                                115
# 117                                                116
# 118                                                117
# 119                                                118
# 120                                                119
# 121                                                120
# 122                                                121
# 123                                                122
# 124                                                123
# 125                                                124
# 126                                                125
# 127                                                126
# 128                                                127
# 129                                                128
# ...

# %%
df = df.drop(np.arange(180,len(df)), axis=0).reset_index(drop=True)
df.tail(30)
# Out:
#                   HDI_rank                             country  reference_1  \
# 150                    149                            Djibouti          NaN
# 151                    150                         Timor-Leste          NaN
# 152                    151                            Zimbabwe          NaN
# 153                    152                                Togo          NaN
# 154                    153                               Yemen          NaN
# 155                    154                              Uganda          NaN
# 156                    155                              Gambia          NaN
# 157  LOW HUMAN DEVELOPMENT                                 NaN          NaN
# 158                    156                             Senegal          NaN
# 159                    157                             Eritrea          NaN
# 160                    158                             Nigeria          NaN
# ...

# %%
hdi_rank_categories = ["HIGH HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "LOW HUMAN DEVELOPMENT"]
df = df.drop(df[df["HDI_rank"].isin(hdi_rank_categories)].index, axis=0).reset_index(drop=True)
df.loc[:, "HDI category"] = np.where(df["HDI_rank"] > 155,"LOW HUMAN DEVELOPMENT",np.where(df["HDI_rank"] > 70,"MEDIUM HUMAN DEVELOPMENT","HIGH HUMAN DEVELOPMENT"))
df.sort_values(by="HDI_rank", inplace=True)
df.head()
# Out:
#   HDI_rank    country  reference_1 GEM_rank GEM_value  reference_2  \
# 0        1    Iceland          NaN        5     0.862          NaN
# 1        2     Norway          NaN        1     0.910          NaN
# 2        3  Australia          NaN        8     0.847          NaN
# 3        4     Canada          NaN       10     0.820          NaN
# 4        5    Ireland          NaN       19     0.699          NaN
#
#   Seats_parlia_wom reference_3 Fem _le_snr_offi_mana reference_4  \
# 0             31.7         NaN                    27         NaN
# 1             37.9         NaN                    30         NaN
# 2             28.3         NaN                    37         NaN
# 3             24.3         NaN                    36         NaN
# 4             14.2         NaN                    31         NaN
#
#   Fem_profes_techn_work reference_5 Ratio_esti_ fem_male_earn_ incom  \
# 0                    56         NaN                             0.72
# ...

# %%
df.tail(5)
# Out:
#     HDI_rank        country  reference_1 GEM_rank GEM_value  reference_2  \
# 172      173           Mali          NaN       ..        ..          NaN
# 173      174          Niger          NaN       ..        ..          NaN
# 174      175  Guinea-Bissau          NaN       ..        ..          NaN
# 175      176   Burkina Faso          NaN       ..        ..          NaN
# 176      177   Sierra Leone          NaN       ..        ..          NaN
#
#     Seats_parlia_wom reference_3 Fem _le_snr_offi_mana reference_4  \
# 172             10.2         NaN                    ..         NaN
# 173             12.4         NaN                    ..         NaN
# 174             14.0         NaN                    ..         NaN
# 175             11.7         NaN                    ..         NaN
# 176             14.5         NaN                    ..         NaN
#
#     Fem_profes_techn_work reference_5 Ratio_esti_ fem_male_earn_ incom  \
# ...
