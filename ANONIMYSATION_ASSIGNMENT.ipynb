# %% [markdown]
# ### Let us have a view on our data

# %%
import pandas as pd
import geopandas as gd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\PCHOME\Desktop\Jasminehelene\Open_data_dcdj_courses\data-wrangling-and-validation\data\lesson-programmatic\patient-data-anonymisation-exercise.csv")
df.head(20)
# Out:
#                               PATIENT_ID                 START  \
# 0   034e9e3b-2def-4559-bb2a-7850888ae060  2010-01-23T17:45:28Z
# 1   034e9e3b-2def-4559-bb2a-7850888ae060  2012-01-23T17:45:28Z
# 2   034e9e3b-2def-4559-bb2a-7850888ae060  2015-01-26T17:45:28Z
# 3   034e9e3b-2def-4559-bb2a-7850888ae060  2016-12-29T17:45:28Z
# 4   034e9e3b-2def-4559-bb2a-7850888ae060  2017-01-09T17:45:28Z
# 5   034e9e3b-2def-4559-bb2a-7850888ae060  2018-01-29T17:45:28Z
# 6   1d604da9-9a81-4ba9-80c2-de3375d59b40  2001-05-01T15:02:18Z
# 7   1d604da9-9a81-4ba9-80c2-de3375d59b40  2011-07-28T15:02:18Z
# 8   1d604da9-9a81-4ba9-80c2-de3375d59b40  2011-12-08T15:02:18Z
# 9   1d604da9-9a81-4ba9-80c2-de3375d59b40  2014-07-31T15:02:18Z
# 10  1d604da9-9a81-4ba9-80c2-de3375d59b40  2017-08-03T15:02:18Z
# 11  1d604da9-9a81-4ba9-80c2-de3375d59b40  2019-03-20T15:02:18Z
# 12  10339b10-3cd1-4ac3-ac13-ec26728cb592  2010-07-27T12:58:08Z
# 13  10339b10-3cd1-4ac3-ac13-ec26728cb592  2011-05-13T12:58:08Z
# 14  10339b10-3cd1-4ac3-ac13-ec26728cb592  2011-05-24T12:58:08Z
# 15  10339b10-3cd1-4ac3-ac13-ec26728cb592  2011-08-02T12:58:08Z
# 16  10339b10-3cd1-4ac3-ac13-ec26728cb592  2011-08-16T12:58:08Z
# 17  10339b10-3cd1-4ac3-ac13-ec26728cb592  2011-08-11T12:58:08Z
# 18  10339b10-3cd1-4ac3-ac13-ec26728cb592  2014-08-05T12:58:08Z
# 19  10339b10-3cd1-4ac3-ac13-ec26728cb592  2017-01-22T12:58:08Z
#
#                     STOP ENCOUNTERCLASS  \
# 0   2010-01-23T18:10:28Z     ambulatory
# 1   2012-01-23T18:00:28Z       wellness
# 2   2015-01-26T18:15:28Z       wellness
# 3   2016-12-29T18:00:28Z     ambulatory
# 4   2017-01-09T18:00:28Z     outpatient
# 5   2018-01-29T18:00:28Z       wellness
# 6   2001-05-01T15:17:18Z     ambulatory
# 7   2011-07-28T15:17:18Z       wellness
# 8   2011-12-08T15:17:18Z     ambulatory
# 9   2014-07-31T15:17:18Z       wellness
# 10  2017-08-03T15:32:18Z       wellness
# 11  2019-03-20T15:17:18Z     ambulatory
# 12  2010-07-27T13:28:08Z       wellness
# 13  2011-05-13T13:13:08Z     ambulatory
# 14  2011-05-24T13:13:08Z     urgentcare
# 15  2011-08-02T13:13:08Z       wellness
# 16  2011-08-16T13:13:08Z     outpatient
# 17  2011-08-11T13:13:08Z     ambulatory
# 18  2014-08-05T13:13:08Z       wellness
# 19  2017-01-22T14:11:08Z      emergency
#
#                                    DESCRIPTION  TOTAL_CLAIM_COST  \
# 0                        Encounter for symptom            129.16
# 1   General examination of patient (procedure)            129.16
# 2   General examination of patient (procedure)            129.16
# 3                        Encounter for symptom            129.16
# 4           Encounter for check up (procedure)            129.16
# 5   General examination of patient (procedure)            129.16
# 6                        Encounter for symptom            129.16
# 7   General examination of patient (procedure)            129.16
# 8                        Encounter for symptom            129.16
# 9   General examination of patient (procedure)            129.16
# 10  General examination of patient (procedure)            129.16
# 11                       Encounter for symptom            129.16
# 12  General examination of patient (procedure)            129.16
# 13                       Encounter for symptom            129.16
# 14              Urgent care clinic (procedure)            129.16
# 15  General examination of patient (procedure)            129.16
# 16          Encounter for check up (procedure)            129.16
# 17                       Encounter for symptom            129.16
# 18  General examination of patient (procedure)            129.16
# 19        Emergency room admission (procedure)            129.16
#
#     PAYER_COVERAGE            REASONDESCRIPTION   BIRTHDATE DEATHDATE  ...  \
# 0            54.16  Acute bronchitis (disorder)  14/11/1983       NaN  ...
# 1           129.16                          NaN  14/11/1983       NaN  ...
# 2           129.16                          NaN  14/11/1983       NaN  ...
# 3            54.16  Acute bronchitis (disorder)  14/11/1983       NaN  ...
# 4            54.16                          NaN  14/11/1983       NaN  ...
# 5           129.16                          NaN  14/11/1983       NaN  ...
# 6             0.00         Sinusitis (disorder)  25/05/1989       NaN  ...
# 7             0.00                          NaN  25/05/1989       NaN  ...
# 8             0.00   Viral sinusitis (disorder)  25/05/1989       NaN  ...
# 9             0.00                          NaN  25/05/1989       NaN  ...
# 10            0.00                          NaN  25/05/1989       NaN  ...
# 11            0.00   Viral sinusitis (disorder)  25/05/1989       NaN  ...
# 12          129.16                          NaN  02/06/1992       NaN  ...
# 13           49.16  Acute bronchitis (disorder)  02/06/1992       NaN  ...
# 14            0.00                          NaN  02/06/1992       NaN  ...
# 15          129.16                          NaN  02/06/1992       NaN  ...
# 16            0.00                          NaN  02/06/1992       NaN  ...
# 17           49.16   Viral sinusitis (disorder)  02/06/1992       NaN  ...
# 18          129.16                          NaN  02/06/1992       NaN  ...
# 19           49.16                          NaN  02/06/1992       NaN  ...
#
#       ETHNICITY GENDER                        BIRTHPLACE  \
# 0   nonhispanic      M        Danvers  Massachusetts  US
# 1   nonhispanic      M        Danvers  Massachusetts  US
# 2   nonhispanic      M        Danvers  Massachusetts  US
# 3   nonhispanic      M        Danvers  Massachusetts  US
# 4   nonhispanic      M        Danvers  Massachusetts  US
# 5   nonhispanic      M        Danvers  Massachusetts  US
# 6      hispanic      M  Marigot  Saint Andrew Parish  DM
# 7      hispanic      M  Marigot  Saint Andrew Parish  DM
# 8      hispanic      M  Marigot  Saint Andrew Parish  DM
# 9      hispanic      M  Marigot  Saint Andrew Parish  DM
# 10     hispanic      M  Marigot  Saint Andrew Parish  DM
# 11     hispanic      M  Marigot  Saint Andrew Parish  DM
# 12  nonhispanic      M    Springfield  Massachusetts  US
# 13  nonhispanic      M    Springfield  Massachusetts  US
# 14  nonhispanic      M    Springfield  Massachusetts  US
# 15  nonhispanic      M    Springfield  Massachusetts  US
# 16  nonhispanic      M    Springfield  Massachusetts  US
# 17  nonhispanic      M    Springfield  Massachusetts  US
# 18  nonhispanic      M    Springfield  Massachusetts  US
# 19  nonhispanic      M    Springfield  Massachusetts  US
#
#                        ADDRESS        CITY          STATE            COUNTY  \
# 0     422 Farrell Path Unit 69  Somerville  Massachusetts  Middlesex County
# 1     422 Farrell Path Unit 69  Somerville  Massachusetts  Middlesex County
# 2     422 Farrell Path Unit 69  Somerville  Massachusetts  Middlesex County
# 3     422 Farrell Path Unit 69  Somerville  Massachusetts  Middlesex County
# 4     422 Farrell Path Unit 69  Somerville  Massachusetts  Middlesex County
# 5     422 Farrell Path Unit 69  Somerville  Massachusetts  Middlesex County
# 6   427 Balistreri Way Unit 19    Chicopee  Massachusetts    Hampden County
# 7   427 Balistreri Way Unit 19    Chicopee  Massachusetts    Hampden County
# 8   427 Balistreri Way Unit 19    Chicopee  Massachusetts    Hampden County
# 9   427 Balistreri Way Unit 19    Chicopee  Massachusetts    Hampden County
# 10  427 Balistreri Way Unit 19    Chicopee  Massachusetts    Hampden County
# 11  427 Balistreri Way Unit 19    Chicopee  Massachusetts    Hampden County
# 12   1056 Harris Lane Suite 70    Chicopee  Massachusetts    Hampden County
# 13   1056 Harris Lane Suite 70    Chicopee  Massachusetts    Hampden County
# 14   1056 Harris Lane Suite 70    Chicopee  Massachusetts    Hampden County
# 15   1056 Harris Lane Suite 70    Chicopee  Massachusetts    Hampden County
# 16   1056 Harris Lane Suite 70    Chicopee  Massachusetts    Hampden County
# 17   1056 Harris Lane Suite 70    Chicopee  Massachusetts    Hampden County
# 18   1056 Harris Lane Suite 70    Chicopee  Massachusetts    Hampden County
# 19   1056 Harris Lane Suite 70    Chicopee  Massachusetts    Hampden County
#
#        ZIP        LAT        LON
# 0   2143.0  42.360697 -71.126531
# 1   2143.0  42.360697 -71.126531
# 2   2143.0  42.360697 -71.126531
# 3   2143.0  42.360697 -71.126531
# 4   2143.0  42.360697 -71.126531
# 5   2143.0  42.360697 -71.126531
# 6   1013.0  42.228354 -72.562951
# 7   1013.0  42.228354 -72.562951
# 8   1013.0  42.228354 -72.562951
# 9   1013.0  42.228354 -72.562951
# 10  1013.0  42.228354 -72.562951
# 11  1013.0  42.228354 -72.562951
# 12  1020.0  42.181642 -72.608842
# 13  1020.0  42.181642 -72.608842
# 14  1020.0  42.181642 -72.608842
# 15  1020.0  42.181642 -72.608842
# 16  1020.0  42.181642 -72.608842
# 17  1020.0  42.181642 -72.608842
# 18  1020.0  42.181642 -72.608842
# 19  1020.0  42.181642 -72.608842
#
# [20 rows x 28 columns]

# %% [markdown]
#    ### Let us get some informations on this dataframe

# %% [markdown]
#    ### Let us consider the story of the patient called Carmelia Konopelski

# %%
df[df["PATIENT_ID"] == "71ba0469-f0cc-4177-ac70-ea07cb01c8b8"]
# Out:
#                                PATIENT_ID                 START  \
# 703  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2002-01-15T20:46:46Z
# 704  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2002-01-25T20:46:46Z
# 705  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2002-11-28T20:46:46Z
# 706  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2003-04-29T20:46:46Z
# 707  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2003-05-11T20:46:46Z
# ..                                    ...                   ...
# 783  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2012-05-08T20:46:46Z
# 784  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2012-05-08T20:46:46Z
# 785  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2012-05-08T20:46:46Z
# 786  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2012-08-14T20:46:46Z
# 787  71ba0469-f0cc-4177-ac70-ea07cb01c8b8  2012-11-20T20:46:46Z
#
#                      STOP ENCOUNTERCLASS  \
# 703  2002-01-15T21:01:46Z     ambulatory
# 704  2002-01-25T21:37:46Z     ambulatory
# 705  2002-12-12T20:46:46Z     ambulatory
# 706  2003-04-29T21:01:46Z       wellness
# 707  2003-05-11T21:01:46Z     ambulatory
# ..                    ...            ...
# 783  2012-05-08T21:01:46Z     ambulatory
# 784  2012-05-09T21:07:46Z      inpatient
# 785  2012-05-09T21:16:46Z      inpatient
# 786  2012-08-14T21:01:46Z     ambulatory
# 787  2012-11-20T21:01:46Z     ambulatory
#
#                                    DESCRIPTION  TOTAL_CLAIM_COST  \
# 703                      Encounter for problem            129.16
# 704                      Encounter for problem            129.16
# 705                      Encounter for symptom            129.16
# 706               Well child visit (procedure)            129.16
# 707                      Encounter for symptom            129.16
# ..                                         ...               ...
# 783  Postoperative follow-up visit (procedure)            129.16
# 784    Screening surveillance (regime/therapy)            129.16
# 785       Gynecology service (qualifier value)            129.16
# 786  Postoperative follow-up visit (procedure)            129.16
# 787  Postoperative follow-up visit (procedure)            129.16
#
#      PAYER_COVERAGE                                  REASONDESCRIPTION  \
# 703           54.16                                                NaN
# 704           54.16                                                NaN
# 705           54.16  Perennial allergic rhinitis with seasonal vari...
# 706           54.16                                                NaN
# 707           54.16               Streptococcal sore throat (disorder)
# ..              ...                                                ...
# 783           54.16            Malignant neoplasm of breast (disorder)
# 784           54.16            Malignant neoplasm of breast (disorder)
# 785           54.16            Malignant neoplasm of breast (disorder)
# 786           54.16            Malignant neoplasm of breast (disorder)
# 787           54.16            Malignant neoplasm of breast (disorder)
#
#       BIRTHDATE   DEATHDATE  ...    ETHNICITY GENDER              BIRTHPLACE  \
# 703  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 704  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 705  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 706  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 707  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# ..          ...         ...  ...          ...    ...                     ...
# 783  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 784  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 785  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 786  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
# 787  21/11/2000  21/11/2012  ...  nonhispanic      F  Lee  Massachusetts  US
#
#                  ADDRESS     CITY          STATE            COUNTY ZIP  \
# 703  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 704  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 705  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 706  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 707  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# ..                   ...      ...            ...               ...  ..
# 783  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 784  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 785  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 786  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
# 787  1025 Collier Arcade  Ashland  Massachusetts  Middlesex County NaN
#
#            LAT        LON
# 703  42.291986 -71.463724
# 704  42.291986 -71.463724
# 705  42.291986 -71.463724
# 706  42.291986 -71.463724
# 707  42.291986 -71.463724
# ..         ...        ...
# 783  42.291986 -71.463724
# 784  42.291986 -71.463724
# 785  42.291986 -71.463724
# 786  42.291986 -71.463724
# 787  42.291986 -71.463724
#
# [85 rows x 28 columns]

# %% [markdown]
# ### Let us get some informations on our dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53346 entries, 0 to 53345
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PATIENT_ID         53346 non-null  object
#  1   START              53346 non-null  object
#  2   STOP               53346 non-null  object
#  3   ENCOUNTERCLASS     53346 non-null  object
#  4   DESCRIPTION        53346 non-null  object
#  5   TOTAL_CLAIM_COST   53346 non-null  float64
#  6   PAYER_COVERAGE     53346 non-null  float64
#  7   REASONDESCRIPTION  13777 non-null  object
#  8   BIRTHDATE          53346 non-null  object
#  9   DEATHDATE          14287 non-null  object
#  10  SSN                53346 non-null  object
#  11  DRIVERS            49285 non-null  object
#  12  PASSPORT           46965 non-null  object
#  13  FIRST              53346 non-null  object
#  14  LAST               53346 non-null  object
#  15  MAIDEN             16597 non-null  object
#  16  MARITAL            43628 non-null  object
#  17  RACE               53346 non-null  object
#  18  ETHNICITY          53346 non-null  object
#  19  GENDER             53346 non-null  object
#  20  BIRTHPLACE         53346 non-null  object
#  21  ADDRESS            53346 non-null  object
#  22  CITY               53346 non-null  object
#  23  STATE              53346 non-null  object
#  24  COUNTY             53346 non-null  object
#  25  ZIP                28239 non-null  float64
#  26  LAT                53346 non-null  float64
#  27  LON                53346 non-null  float64
# dtypes: float64(5), object(23)
# memory usage: 11.4+ MB

# %% [markdown]
# ### Let us use geopandas to see the physical location of our data

# %%
gdf = gd.GeoDataFrame(df, crs="EPSG:4326", geometry=gd.points_from_xy(df.LON, df.LAT))

# %% [markdown]
# ### Unfortunately before locating those addresses , we must project them back on the Mercator 'web

# %%
import contextily as ctx

# reproject
gdf = gdf.to_crs(epsg=3857)
ax = gdf.plot(figsize=(20, 20), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax=ax, source=ctx.providers.Stamen.TonerLite, zoom=12)
ax.set_axis_off()
# Out:
# C:\Users\PCHOME\Anaconda3\envs\Data_cleaning\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# ### Let us drop the columns which are  not needed

# %%
suppression = ["SSN", "DRIVERS", "PASSPORT", "FIRST", "LAST", "MAIDEN", "ADDRESS", "ZIP"]


df.drop(suppression, axis=1, inplace=True)

# %% [markdown]
# ### Let us generate a unique ID  and random code

# %%
import uuid

str(uuid.uuid4())
# Out:
# 'f27d2b8c-5803-4368-ab0a-f1c7cfe5f6c4'

# %% [markdown]
# ### Standard deviation

# %%
import numpy as np

sigma = 0.001 
mu = 1 

np.random.normal(mu, sigma)
# Out:
# 1.000046209111728

# %% [markdown]
# ### Let us create a pseudonymised version of a data,pseudonymisation :replacement of identifying data with randomised values. This can be reversable

# %%
from collections import defaultdict

class Pseudonymise:
    
    def __init__(self, sigma=0.001):
        # Initialiser un dictionnaire par défaut, cela crée un élément de dictionnaire par défaut s'il n'existe pas
        # Nous utilisons cette méthode pour garantir l'intégrité des données tout en les rendant aléatoires
        # http://ikigomu.com/?p=28
        self.sigma = sigma
        self.mu = 0 # Nous voulons nous écarter de la vérité
        # Pseudo-patient dict
        self.pp = defaultdict(lambda: {"uuid":str(uuid.uuid4()),
                                       "lat": np.random.normal(self.mu, self.sigma),
                                       "lon": np.random.normal(self.mu, self.sigma)
                                      })
        
    def create_data(self, identities):
        """
        Pour chaque identité unique produire un UUID unique, et un gaussien randomisé "LAT" et "LON".

        Parameters
        ----------
        identities: liste des chaînes de caractères

        Returns
        -------
        dict
            Chaque entrée de dict contient un enregistrement contenant un "uuid" et un modificateur pour "lat" et "lon".
        """
        for _id in identities:
            self.pp[_id]
        return self.pp
    
    def redact(self, row):
        """
        Pour une ligne donnée dans un dataframe, retournez la version pseudonymisée de "PATIENT_ID", "LAT", "LON".
        
        Parameters:
        row : Ligne de la trame de données
        
        row:
        DataFrame tranche de ligne 
        """
        return [
            self.pp[row["PATIENT_ID"]]["uuid"],
            row["LAT"] + self.pp[row["PATIENT_ID"]]["lat"],
            row["LON"] + self.pp[row["PATIENT_ID"]]["lon"],
        ]

p = Pseudonymise()
pp_data = p.create_data(df["PATIENT_ID"])
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html
fields = ["PATIENT_ID", "LAT", "LON"]

# %%
df[fields] = df[fields].apply(p.redact, axis=1, result_type="expand")

# %% [markdown]
# ### Pertubation

# %%
# The datetime module will help us to return information about the date object , because in python a a date is not a data type on its own .

import datetime

# let us create a class called pertubation that will help us to pertubate the birthdate and deathdate 

class pertubation:
    
# The built-in _init_() function is always executed  when the class is initiated, the self parameters is a reference to the current instance of the class and is used to access variables that belong too the class

# knowing that we will manipulate date here , let us called the fonction  timedelta()

    def __init__(self):
         self.days = datetime.timedelta(days=1000)

# strptime();format data object to readable strings
# let us create a function that pertubate the birthdate by adding 1000 days on it  

    def pertubation_birth_date(self, birth_date): 
        previous_birth_date = datetime.datetime.strptime(birth_date, "%d/%m/%Y")
        new_birth_date = previous_birth_date + self.days
        return new_birth_date.strftime("%d/%m/%Y")

    def reverse_birth_date(self, birth_date):
        previous_birth_date = datetime.datetime.strptime(birth_date, "%d/%m/%Y")
        new_birth_date = previous_birth_date - self.days
        return new_birth_date.strftime("%d/%m/%Y")

    def pertubation_death_date(self, death_date):
        if isinstance(death_date, str):
            previous_death_date = datetime.datetime.strptime(death_date, "%d/%m/%Y")
            new_death_date = previous_death_date + self.days
            return new_death_date.strftime("%d/%m/%Y")

    def reverse_death_date(self, death_date):
        if isinstance(death_date, str):
            previous_death_date = datetime.datetime.strptime(death_date, "%d/%m/%Y")
            new_death_date = previous_death_date - self.days
            return new_death_date.strftime("%d/%m/%Y")

    def pertubation_date(self, row):
        return [
            row["PATIENT_ID"],
            self.pertubation_birth_date(row["BIRTHDATE"]),
            self.pertubation_death_date(row["DEATHDATE"])
        ]

    def revert_pertubation(self, row):
        return [
            row["PATIENT_ID"],
            self.reverse_birth_date(row["BIRTHDATE"]),
            self.reverse_death_date(row["DEATHDATE"])
        ]



pertubation = pertubation()
fields = ["PATIENT_ID", "BIRTHDATE", "DEATHDATE"]

# %% [markdown]
# ##### Pertubation

# %%
df[fields] = df[fields].apply(pertubation.pertubation_date, axis=1, result_type="expand")
df.head()

# %% [markdown]
# ### REVERSE  PERTUBATION

# %%
df[fields] = df[fields].apply(pertubation.revert_pertubation, axis=1, result_type="expand")
df.head()

# %%
df.describe()
# Out:
#        TOTAL_CLAIM_COST  PAYER_COVERAGE           ZIP           LAT  \
# count      53346.000000    53346.000000  28239.000000  53346.000000
# mean         128.750290       61.998867   2030.527214     42.260817
# std            4.582823       43.613335    433.861542      0.295230
# min           77.490000        0.000000   1001.000000     41.337822
# 25%          129.160000       17.490000   1880.000000     42.130207
# 50%          129.160000       69.160000   2126.000000     42.309085
# 75%          129.160000       89.160000   2189.000000     42.425397
# max          129.160000      129.160000   2861.000000     42.894987
#
#                 LON
# count  53346.000000
# mean     -71.343250
# std        0.629145
# min      -73.381411
# 25%      -71.653259
# 50%      -71.163006
# 75%      -71.022607
# max      -69.941054

# %%
df[["DEATHDATE"]].describe()
# Out:
#          DEATHDATE
# count        14287
# unique         171
# top     02/05/2009
# freq          2006

# %%
df[["DEATHDATE"]].median()
# Out:
# Series([], dtype: float64)

# %%
dfo = pd.read_csv(r"C:/Users/PCHOME/Desktop/Jasminehelene/Open_data_dcdj_courses/data-wrangling-and-validation/data/lesson-programmatic/patient-data-anonymisation-exercise.csv")

# %%
df = dfo.copy()
# Let us convert the date in python's date 
for c in ["START", "STOP", "BIRTHDATE", "DEATHDATE"]:
    dfo[c] = dfo[c].apply(lambda x: pd.to_datetime(x, errors="coerce", dayfirst=True).date())
    

# let us filter the medical  treatment for the deceased patients 
dfo = dfo[dfo.STOP==dfo.DEATHDATE]
dfo.sort_values(by="STOP", inplace=True)
dfo.drop_duplicates(subset="PATIENT_ID", keep="last", inplace=True)


# Let us create DEATHAGE

# here is a very approximatif calculation for DEATHAGE
dfo["DEATHAGE"] = dfo.DEATHDATE.apply(lambda x: x.year) - dfo.BIRTHDATE.apply(lambda x: x.year)

# Now let us divide them into differents badges 
dfo["DEATHAGE"].hist(bins=10)

# %%
import datetime as dt

dfo["now"]=dt.datetime.now()
dfo["DEATHAGE"] = dfo["now"].dt.date-dfo["DEATHDATE"]

dfo
# Out:
#                                  PATIENT_ID       START        STOP  \
# 17464  67156a1d-2e86-42e0-a81c-6ce3af24aca4  1926-03-05  1926-03-05
# 6574   24a7b5ac-a573-4469-be04-6f02673cd157  1927-07-08  1927-07-08
# 39451  344de08b-bae0-4d79-b89e-a2b6204e1a21  1958-01-03  1958-01-03
# 52548  b940dd35-39e3-49d9-918a-316db1e223e3  1962-12-29  1962-12-29
# 21413  fd1e9a6d-5b50-4a6f-bd61-c884ab89f5c6  1967-01-07  1967-01-07
# ...                                     ...         ...         ...
# 48996  aa266066-bb51-4990-be9b-0a49fc65303e  2017-10-07  2017-10-08
# 1813   c563f50c-54a9-4b37-9028-bff3db7e3e27  2017-11-24  2017-11-24
# 38205  41de7636-253c-4360-8cf7-6fc166b0448b  2018-06-06  2018-06-06
# 35080  ea521af0-e6c4-4a3c-899c-89c35c49287d  2019-01-03  2019-01-03
# 7988   3c2bfff1-8a3f-4b9c-bc18-e7ea6562e436  2019-05-15  2019-05-15
#
#       ENCOUNTERCLASS                         DESCRIPTION  TOTAL_CLAIM_COST  \
# 17464       wellness                 Death Certification            129.16
# 6574        wellness                 Death Certification            129.16
# 39451       wellness                 Death Certification            129.16
# 52548       wellness                 Death Certification            129.16
# 21413      emergency                      Cardiac Arrest            129.16
# ...              ...                                 ...               ...
# 48996      inpatient            Inpatient stay (finding)            129.16
# 1813       emergency            Emergency Room Admission            129.16
# 38205      emergency                              Stroke            129.16
# 35080     outpatient  Encounter for check up (procedure)            129.16
# 7988        wellness                 Death Certification            129.16
#
#        PAYER_COVERAGE                            REASONDESCRIPTION  \
# 17464            0.00                                          NaN
# 6574             0.00                                          NaN
# 39451            0.00                                          NaN
# 52548            0.00                                          NaN
# 21413           69.16                                          NaN
# ...               ...                                          ...
# 48996            0.00  Chronic congestive heart failure (disorder)
# 1813             0.00                                Drug overdose
# 38205           29.16                                          NaN
# 35080           69.16                                          NaN
# 7988             0.00                                          NaN
#
#         BIRTHDATE   DEATHDATE  ...                           BIRTHPLACE  \
# 17464  1913-05-30  1926-03-05  ...          Boylston  Massachusetts  US
# 6574   1923-06-22  1927-07-08  ...  West Springfield  Massachusetts  US
# 39451  1941-02-14  1958-01-03  ...       Southbridge  Massachusetts  US
# 52548  1952-01-05  1962-12-29  ...       New Bedford  Massachusetts  US
# 21413  1942-05-23  1967-01-07  ...          Brockton  Massachusetts  US
# ...           ...         ...  ...                                  ...
# 48996  1954-09-22  2017-10-08  ...          Lawrence  Massachusetts  US
# 1813   1997-12-14  2017-11-24  ...           Medford  Massachusetts  US
# 38205  1947-11-26  2018-06-06  ...        Fall River  Massachusetts  US
# 35080  1954-06-10  2019-01-03  ...            Warren  Massachusetts  US
# 7988   2018-07-25  2019-05-15  ...        Sturbridge  Massachusetts  US
#
#                              ADDRESS       CITY          STATE  \
# 17464  628 Welch Trafficway Suite 18     Boston  Massachusetts
# 6574     263 Cummings Landing Apt 63  Brookline  Massachusetts
# 39451  449 Shields Extension Unit 55    Hanover  Massachusetts
# 52548     281 Walter Harbor Suite 62   Westport  Massachusetts
# 21413  199 Heathcote Skyway Suite 70    Chatham  Massachusetts
# ...                              ...        ...            ...
# 48996            353 Bradtke Viaduct     Quincy  Massachusetts
# 1813             546 Kuhlman Mission       Lynn  Massachusetts
# 38205      531 Murazik Estate Apt 25     Boston  Massachusetts
# 35080           797 Von Alley Apt 95     Malden  Massachusetts
# 7988              121 Gorczany Haven      Salem  Massachusetts
#
#                   COUNTY     ZIP        LAT        LON   DEATHAGE  \
# 17464     Suffolk County  2163.0  42.205429 -71.126814 34434 days
# 6574      Norfolk County     NaN  42.353288 -71.091628 33944 days
# 39451    Plymouth County     NaN  42.082996 -70.826976 22807 days
# 52548     Bristol County     NaN  41.599499 -71.066024 20986 days
# 21413  Barnstable County  2633.0  41.693682 -70.010983 19516 days
# ...                  ...     ...        ...        ...        ...
# 48996     Norfolk County  2170.0  42.279688 -71.113605   979 days
# 1813        Essex County  1940.0  42.437974 -71.035246   932 days
# 38205     Suffolk County  2126.0  42.385670 -71.014563   738 days
# 35080   Middlesex County     NaN  42.450744 -71.022812   527 days
# 7988        Essex County     NaN  42.517922 -70.908863   395 days
#
#                              now
# 17464 2020-06-13 16:47:17.490404
# 6574  2020-06-13 16:47:17.490404
# 39451 2020-06-13 16:47:17.490404
# 52548 2020-06-13 16:47:17.490404
# 21413 2020-06-13 16:47:17.490404
# ...                          ...
# 48996 2020-06-13 16:47:17.490404
# 1813  2020-06-13 16:47:17.490404
# 38205 2020-06-13 16:47:17.490404
# 35080 2020-06-13 16:47:17.490404
# 7988  2020-06-13 16:47:17.490404
#
# [70 rows x 30 columns]

# %%
from datetime import timedelta

# %%
labels = "DESCRIPTION"
dfo["DEATHAGE"] = pd.cut(dfo["DEATHAGE"],bins=[timedelta(days=500),timedelta(days=1000),timedelta(days=2000),timedelta(days=2500),timedelta(days=3000)timedelta(days=3500),timedelta(days=4000),timedelta(days=4500)],include_lowest = True)
dfo
# Out:
#                                  PATIENT_ID       START        STOP  \
# 17464  67156a1d-2e86-42e0-a81c-6ce3af24aca4  1926-03-05  1926-03-05
# 6574   24a7b5ac-a573-4469-be04-6f02673cd157  1927-07-08  1927-07-08
# 39451  344de08b-bae0-4d79-b89e-a2b6204e1a21  1958-01-03  1958-01-03
# 52548  b940dd35-39e3-49d9-918a-316db1e223e3  1962-12-29  1962-12-29
# 21413  fd1e9a6d-5b50-4a6f-bd61-c884ab89f5c6  1967-01-07  1967-01-07
# ...                                     ...         ...         ...
# 48996  aa266066-bb51-4990-be9b-0a49fc65303e  2017-10-07  2017-10-08
# 1813   c563f50c-54a9-4b37-9028-bff3db7e3e27  2017-11-24  2017-11-24
# 38205  41de7636-253c-4360-8cf7-6fc166b0448b  2018-06-06  2018-06-06
# 35080  ea521af0-e6c4-4a3c-899c-89c35c49287d  2019-01-03  2019-01-03
# 7988   3c2bfff1-8a3f-4b9c-bc18-e7ea6562e436  2019-05-15  2019-05-15
#
#       ENCOUNTERCLASS                         DESCRIPTION  TOTAL_CLAIM_COST  \
# 17464       wellness                 Death Certification            129.16
# 6574        wellness                 Death Certification            129.16
# 39451       wellness                 Death Certification            129.16
# 52548       wellness                 Death Certification            129.16
# 21413      emergency                      Cardiac Arrest            129.16
# ...              ...                                 ...               ...
# 48996      inpatient            Inpatient stay (finding)            129.16
# 1813       emergency            Emergency Room Admission            129.16
# 38205      emergency                              Stroke            129.16
# 35080     outpatient  Encounter for check up (procedure)            129.16
# 7988        wellness                 Death Certification            129.16
#
#        PAYER_COVERAGE                            REASONDESCRIPTION  \
# 17464            0.00                                          NaN
# 6574             0.00                                          NaN
# 39451            0.00                                          NaN
# 52548            0.00                                          NaN
# 21413           69.16                                          NaN
# ...               ...                                          ...
# 48996            0.00  Chronic congestive heart failure (disorder)
# 1813             0.00                                Drug overdose
# 38205           29.16                                          NaN
# 35080           69.16                                          NaN
# 7988             0.00                                          NaN
#
#         BIRTHDATE   DEATHDATE  ...                           BIRTHPLACE  \
# 17464  1913-05-30  1926-03-05  ...          Boylston  Massachusetts  US
# 6574   1923-06-22  1927-07-08  ...  West Springfield  Massachusetts  US
# 39451  1941-02-14  1958-01-03  ...       Southbridge  Massachusetts  US
# 52548  1952-01-05  1962-12-29  ...       New Bedford  Massachusetts  US
# 21413  1942-05-23  1967-01-07  ...          Brockton  Massachusetts  US
# ...           ...         ...  ...                                  ...
# 48996  1954-09-22  2017-10-08  ...          Lawrence  Massachusetts  US
# 1813   1997-12-14  2017-11-24  ...           Medford  Massachusetts  US
# 38205  1947-11-26  2018-06-06  ...        Fall River  Massachusetts  US
# 35080  1954-06-10  2019-01-03  ...            Warren  Massachusetts  US
# 7988   2018-07-25  2019-05-15  ...        Sturbridge  Massachusetts  US
#
#                              ADDRESS       CITY          STATE  \
# 17464  628 Welch Trafficway Suite 18     Boston  Massachusetts
# 6574     263 Cummings Landing Apt 63  Brookline  Massachusetts
# 39451  449 Shields Extension Unit 55    Hanover  Massachusetts
# 52548     281 Walter Harbor Suite 62   Westport  Massachusetts
# 21413  199 Heathcote Skyway Suite 70    Chatham  Massachusetts
# ...                              ...        ...            ...
# 48996            353 Bradtke Viaduct     Quincy  Massachusetts
# 1813             546 Kuhlman Mission       Lynn  Massachusetts
# 38205      531 Murazik Estate Apt 25     Boston  Massachusetts
# 35080           797 Von Alley Apt 95     Malden  Massachusetts
# 7988              121 Gorczany Haven      Salem  Massachusetts
#
#                   COUNTY     ZIP        LAT        LON  \
# 17464     Suffolk County  2163.0  42.205429 -71.126814
# 6574      Norfolk County     NaN  42.353288 -71.091628
# 39451    Plymouth County     NaN  42.082996 -70.826976
# 52548     Bristol County     NaN  41.599499 -71.066024
# 21413  Barnstable County  2633.0  41.693682 -70.010983
# ...                  ...     ...        ...        ...
# 48996     Norfolk County  2170.0  42.279688 -71.113605
# 1813        Essex County  1940.0  42.437974 -71.035246
# 38205     Suffolk County  2126.0  42.385670 -71.014563
# 35080   Middlesex County     NaN  42.450744 -71.022812
# 7988        Essex County     NaN  42.517922 -70.908863
#
#                                              DEATHAGE  \
# 17464                                             NaN
# 6574                                              NaN
# 39451                                             NaN
# 52548                                             NaN
# 21413                                             NaN
# ...                                               ...
# 48996  (499 days 23:59:59.999999, 1000 days 00:00:00]
# 1813   (499 days 23:59:59.999999, 1000 days 00:00:00]
# 38205  (499 days 23:59:59.999999, 1000 days 00:00:00]
# 35080  (499 days 23:59:59.999999, 1000 days 00:00:00]
# 7988                                              NaN
#
#                              now
# 17464 2020-06-13 16:47:17.490404
# 6574  2020-06-13 16:47:17.490404
# 39451 2020-06-13 16:47:17.490404
# 52548 2020-06-13 16:47:17.490404
# 21413 2020-06-13 16:47:17.490404
# ...                          ...
# 48996 2020-06-13 16:47:17.490404
# 1813  2020-06-13 16:47:17.490404
# 38205 2020-06-13 16:47:17.490404
# 35080 2020-06-13 16:47:17.490404
# 7988  2020-06-13 16:47:17.490404
#
# [70 rows x 30 columns]

# %%
dfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70 entries, 17464 to 7988
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PATIENT_ID         70 non-null     object
#  1   START              70 non-null     object
#  2   STOP               70 non-null     object
#  3   ENCOUNTERCLASS     70 non-null     object
#  4   DESCRIPTION        70 non-null     object
#  5   TOTAL_CLAIM_COST   70 non-null     float64
#  6   PAYER_COVERAGE     70 non-null     float64
#  7   REASONDESCRIPTION  10 non-null     object
#  8   BIRTHDATE          70 non-null     object
#  9   DEATHDATE          70 non-null     object
#  10  SSN                70 non-null     object
#  11  DRIVERS            55 non-null     object
#  12  PASSPORT           51 non-null     object
#  13  FIRST              70 non-null     object
#  14  LAST               70 non-null     object
#  15  MAIDEN             15 non-null     object
#  16  MARITAL            46 non-null     object
#  17  RACE               70 non-null     object
#  18  ETHNICITY          70 non-null     object
#  19  GENDER             70 non-null     object
#  20  BIRTHPLACE         70 non-null     object
#  21  ADDRESS            70 non-null     object
#  22  CITY               70 non-null     object
#  23  STATE              70 non-null     object
#  24  COUNTY             70 non-null     object
#  25  ZIP                36 non-null     float64
#  26  LAT                70 non-null     float64
#  27  LON                70 non-null     float64
#  28  DEATHAGE           17 non-null     category
#  29  now                70 non-null     datetime64[ns]
# dtypes: category(1), datetime64[ns](1), float64(5), object(23)
# memory usage: 16.6+ KB

# %%
df1=dfo.groupby("DEATHAGE")["DESCRIPTION"].agg(["value_counts"])
df2=dfo.groupby("DEATHAGE")["TOTAL_CLAIM_COST"].agg(["sum","median"])
df3=df2.join(df1)
df3
# Out:
#                                                                                                sum  \
# DEATHAGE                                       DESCRIPTION
# (499 days 23:59:59.999999, 1000 days 00:00:00] Emergency Room Admission                     516.64
#                                                Encounter for check up (procedure)           516.64
#                                                Inpatient stay (finding)                     516.64
#                                                Stroke                                       516.64
# (1000 days 00:00:00, 2000 days 00:00:00]       Inpatient stay (finding)                    1033.28
#                                                Stroke                                      1033.28
#                                                Death Certification                         1033.28
#                                                Emergency Room Admission                    1033.28
#                                                General examination of patient (procedure)  1033.28
#                                                Myocardial Infarction                       1033.28
# (2000 days 00:00:00, 3000 days 00:00:00]       Stroke                                       645.80
#                                                Emergency Room Admission                     645.80
#                                                Emergency room admission (procedure)         645.80
#                                                Follow-up encounter                          645.80
#
#                                                                                            median  \
# DEATHAGE                                       DESCRIPTION
# (499 days 23:59:59.999999, 1000 days 00:00:00] Emergency Room Admission                    129.16
#                                                Encounter for check up (procedure)          129.16
#                                                Inpatient stay (finding)                    129.16
#                                                Stroke                                      129.16
# (1000 days 00:00:00, 2000 days 00:00:00]       Inpatient stay (finding)                    129.16
#                                                Stroke                                      129.16
#                                                Death Certification                         129.16
#                                                Emergency Room Admission                    129.16
#                                                General examination of patient (procedure)  129.16
#                                                Myocardial Infarction                       129.16
# (2000 days 00:00:00, 3000 days 00:00:00]       Stroke                                      129.16
#                                                Emergency Room Admission                    129.16
#                                                Emergency room admission (procedure)        129.16
#                                                Follow-up encounter                         129.16
#
#                                                                                            value_counts
# DEATHAGE                                       DESCRIPTION
# (499 days 23:59:59.999999, 1000 days 00:00:00] Emergency Room Admission                               1
#                                                Encounter for check up (procedure)                     1
#                                                Inpatient stay (finding)                               1
#                                                Stroke                                                 1
# (1000 days 00:00:00, 2000 days 00:00:00]       Inpatient stay (finding)                               2
#                                                Stroke                                                 2
#                                                Death Certification                                    1
#                                                Emergency Room Admission                               1
#                                                General examination of patient (procedure)             1
#                                                Myocardial Infarction                                  1
# (2000 days 00:00:00, 3000 days 00:00:00]       Stroke                                                 2
#                                                Emergency Room Admission                               1
#                                                Emergency room admission (procedure)                   1
#                                                Follow-up encounter                                    1
